# %%
import qsotools.plotter as qplt

# %%
PP=qplt.PowerPlotter("/Users/nk452/repos/data/high_res_mocks/lapacke-tbb-10zbins/hr-lu-tbb_it1_quadratic_power_estimate_detailed.dat")
# Out:
# There are 10 redshift bins and 25 k bins.

# %%
PP.plotRedshiftBin(9, two_row=True, auto_ylim_xmax=0.1)
# Out:
# z=3.8 Chi-Square / dof: 16.97 / 25.

# %%
PP.plotAll(auto_ylim_xmax=0.1, noise_dom=0.3, two_row=True)
# Out:
# Chi-Square / dof: 216.95 / 250.

# %%
PP.plotMultiDeviation(auto_ylim_xmax=0.1)

# %%
FP = qplt.FisherPlotter("/Users/nk452/repos/data/high_res_mocks/lapacke-tbb-10zbins/hr-lu-tbb_it1_fisher_matrix.dat", 10)

# %%
FP.plotAll()

# %%
FP.plotZBin(1)

# %%
FP.plotKBin(1)

# %%
FP.plotKCrossZbin(1)
